# %%
# !pip install fastapi uvicorn chromadb sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.5/615.5 kB 26.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 67.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 80.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 4.7 MB/s eta 0:00:00
# ...

# %%
from fastapi import FastAPI, UploadFile, File
from chromadb import PersistentClient
from sentence_transformers import SentenceTransformer
import asyncio
import os
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
app = FastAPI()

# Initialize ChromaDB client (You may need to configure the path properly for your environment)
chroma_client = PersistentClient(path="./chroma_data")

# Load Sentence Transformer Model
embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %%
@app.post("/ingest/")
async def ingest_document(file: UploadFile = File(...)):
    content = await file.read()
    embedding = embedding_model.encode(content.decode('utf-8'), show_progress_bar=False)
    chroma_client.add_document(embedding=embedding, document_id=file.filename)
    return {"message": f"{file.filename} ingested successfully"}
# Out:
# ERROR:fastapi:Form data requires "python-multipart" to be installed.
# You can install "python-multipart" with:
#
# pip install python-multipart
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-4f06c250d007> in <cell line: 1>()
#       1 @app.post("/ingest/")
# ----> 2 async def ingest_document(file: UploadFile = File(...)):
#       3     content = await file.read()
#       4     embedding = embedding_model.encode(content.decode('utf-8'), show_progress_bar=False)
#       5     chroma_client.add_document(embedding=embedding, document_id=file.filename)
#
# /usr/local/lib/python3.10/dist-packages/fastapi/routing.py in decorator(func)
#     992     ) -> Callable[[DecoratedCallable], DecoratedCallable]:
#     993         def decorator(func: DecoratedCallable) -> DecoratedCallable:
# --> 994             self.add_api_route(
#     995                 path,
# ...

# %%
# !pip install python-multipart

# %%
from fastapi import FastAPI, UploadFile, File
from chromadb import PersistentClient
from sentence_transformers import SentenceTransformer

app = FastAPI()

# Initialize ChromaDB and Sentence Transformer Model
chroma_client = PersistentClient(path="./chroma_data")
embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# API Endpoint for Ingesting Document
@app.post("/ingest/")
async def ingest_document(file: UploadFile = File(...)):
    content = await file.read()
    embedding = embedding_model.encode(content.decode('utf-8'), show_progress_bar=False)
    chroma_client.add_document(embedding=embedding, document_id=file.filename)
    return {"message": f"{file.filename} ingested successfully"}

# %%
@app.post("/ingest/")
async def ingest_document(file: UploadFile = File(...)):
    content = await file.read()
    embedding = embedding_model.encode(content.decode('utf-8'), show_progress_bar=False)
    chroma_client.add_document(embedding=embedding, document_id=file.filename)
    return {"message": f"{file.filename} ingested successfully"}

# %%
@app.post("/query/")
async def query_document(query: str):
    query_embedding = embedding_model.encode(query)
    results = chroma_client.query(query_embedding=query_embedding, n_results=5)
    return {"results": results}

# %%
from fastapi import FastAPI, UploadFile, File
from chromadb import PersistentClient
from sentence_transformers import SentenceTransformer

app = FastAPI()

# Initialize ChromaDB and Sentence Transformer Model
chroma_client = PersistentClient(path="./chroma_data")
embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

@app.post("/ingest/")
async def ingest_document(file: UploadFile = File(...)):
    content = await file.read()
    embedding = embedding_model.encode(content.decode('utf-8'), show_progress_bar=False)
    chroma_client.add_document(embedding=embedding, document_id=file.filename)
    return {"message": f"{file.filename} ingested successfully"}

@app.post("/query/")
async def query_document(query: str):
    query_embedding = embedding_model.encode(query)
    results = chroma_client.query(query_embedding=query_embedding, n_results=5)
    return {"results": results}

# %%
# Define your FastAPI code as a multi-line string
code = """
from fastapi import FastAPI, UploadFile, File
from chromadb import PersistentClient
from sentence_transformers import SentenceTransformer

app = FastAPI()

# Initialize ChromaDB and Sentence Transformer Model
chroma_client = PersistentClient(path="./chroma_data")
embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

@app.post("/ingest/")
async def ingest_document(file: UploadFile = File(...)):
    content = await file.read()
    embedding = embedding_model.encode(content.decode('utf-8'), show_progress_bar=False)
    chroma_client.add_document(embedding=embedding, document_id=file.filename)
    return {"message": f"{file.filename} ingested successfully"}

@app.post("/query/")
async def query_document(query: str):
    query_embedding = embedding_model.encode(query)
    results = chroma_client.query(query_embedding=query_embedding, n_results=5)
    return {"results": results}
"""

# Save the code to a file named 'main.py'
with open('main.py', 'w') as f:
    f.write(code)

# %%
from google.colab import files
files.download('main.py')

# %%
# !ngrok config add-authtoken 2oUTi7sfhgGjUrSatO33EWDuxf0_7fAN5SAS6GxydHAP94Fv5
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import nest_asyncio
from pyngrok import ngrok
import uvicorn

# Allow asyncio to run in Google Colab
nest_asyncio.apply()

# Open an ngrok tunnel to the server
public_url = ngrok.connect(8000)
print("Public URL:", public_url)

# Run the FastAPI server
uvicorn.run("main:app", host="0.0.0.0", port=8000)
# Out:
# Public URL: NgrokTunnel: "https://602c-35-197-63-184.ngrok-free.app" -> "http://localhost:8000"
# INFO:     Started server process [559]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     2409:40d2:2a:3198:34f1:5ec9:b5b4:c4a3:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     2409:40d2:2a:3198:34f1:5ec9:b5b4:c4a3:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     44.196.175.104:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [559]

# %%
@app.get("/")
async def read_root():
    return {"message": "Welcome to the FastAPI RAG Server"}

# %%
{"message": "Welcome to the FastAPI RAG Server"}
# Out:
# {'message': 'Welcome to the FastAPI RAG Server'}

# %%
from fastapi import FastAPI, UploadFile, File
from chromadb import PersistentClient
from sentence_transformers import SentenceTransformer
import os

app = FastAPI()

# Initialize ChromaDB client with persistent storage
chroma_client = PersistentClient(path="./chroma_data")

# Load Sentence Transformer Model for embeddings
embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

@app.post("/ingest/")
async def ingest_document(file: UploadFile = File(...)):
    content = await file.read()
    embedding = embedding_model.encode(content.decode('utf-8'), show_progress_bar=False)
    chroma_client.add_document(embedding=embedding, document_id=file.filename)
    return {"message": f"{file.filename} ingested successfully"}

@app.post("/query/")
async def query_document(query: str):
    query_embedding = embedding_model.encode(query)
    results = chroma_client.query(query_embedding=query_embedding, n_results=5)
    return {"results": results}

# %%
cd path\to\your\Generative-AI-Assignment
# Out:
# [Errno 2] No such file or directory: 'pathtoyourGenerative-AI-Assignment'
# /content
